# %%
import numpy as np 
import pandas as pd

# %%
df_calidad_aire_08=pd.read_csv('data/datos08.csv',sep=';')
df_calidad_aire_09=pd.read_csv('data/datos09.csv',sep=';')
df_calidad_aire_10=pd.read_csv('data/datos10.csv',sep=';')
df_calidad_aire_11=pd.read_csv('data/datos11.csv',sep=';')
df_calidad_aire_12=pd.read_csv('data/datos12.csv',sep=';')
df_calidad_aire_13=pd.read_csv('data/datos13.csv',sep=';')
df_calidad_aire_14=pd.read_csv('data/datos14.csv',sep=';')
df_calidad_aire_15=pd.read_csv('data/datos15.csv',sep=';')

# %%
df = pd.concat([df_calidad_aire_08,df_calidad_aire_09,df_calidad_aire_10,df_calidad_aire_11,df_calidad_aire_12,df_calidad_aire_13,df_calidad_aire_14,df_calidad_aire_15],axis=0,ignore_index=True)

# %%
Ds = df.columns[[x.startswith('D') for x in df.columns]]

# %%
df_d = df[Ds]

# %%
df_d
# Out:
#         D01   D02   D03   D04   D05   D06   D07   D08   D09   D10  ...   D22  \
# 0      20.0  20.0  14.0  17.0  16.0  11.0  15.0  20.0  17.0  15.0  ...  29.0
# 1      23.0  16.0  13.0  12.0  19.0  25.0  25.0  24.0  20.0  21.0  ...  15.0
# 2      17.0  16.0  15.0  12.0  12.0  16.0  19.0  17.0  17.0  11.0  ...  11.0
# 3      14.0  11.0  10.0   9.0   9.0  11.0   9.0   8.0   8.0   8.0  ...   9.0
# 4       7.0   8.0   8.0   8.0   7.0   8.0   7.0   6.0   7.0   6.0  ...   7.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 12931  90.0  81.0  65.0  88.0  82.0  78.0  75.0  95.0  85.0  78.0  ...  77.0
# 12932  53.0  70.0  82.0  69.0  70.0  75.0  68.0  66.0  62.0  52.0  ...  73.0
# 12933  51.0  68.0  66.0  45.0  21.0  44.0  36.0  34.0  24.0  36.0  ...  29.0
# 12934  61.0  57.0  46.0  27.0  34.0  24.0  33.0  33.0  21.0   7.0  ...  57.0
# 12935  33.0  25.0  27.0  26.0  29.0  37.0  31.0  28.0  35.0  30.0  ...  29.0
#
#         D23   D24   D25   D26   D27   D28   D29   D30   D31
# 0      29.0  26.0  20.0  18.0  24.0  30.0  24.0  27.0  20.0
# 1      14.0  13.0  16.0  19.0  20.0  14.0  17.0   0.0   0.0
# 2      12.0  14.0  15.0  13.0  11.0  14.0  13.0  11.0  11.0
# 3       9.0   9.0   9.0   9.0   9.0   7.0   6.0   7.0   0.0
# 4       6.0   6.0   7.0   7.0   7.0   7.0   7.0   7.0   7.0
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 12931  54.0  71.0  61.0  61.0  64.0  64.0  88.0  71.0  40.0
# 12932  58.0  58.0  59.0  64.0  79.0  66.0  60.0  58.0   0.0
# 12933  28.0  33.0  57.0  46.0  54.0  62.0  45.0  28.0  54.0
# 12934  50.0  26.0  53.0  53.0  52.0  49.0  45.0  33.0   0.0
# 12935  30.0  26.0  34.0  35.0  51.0  42.0  45.0  43.0  32.0
#
# [12936 rows x 31 columns]

# %%
df_d.replace(0,np.nan,inplace=True)
# Out:
# c:\Users\eruit\anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df_d.mean(axis=1)
# Out:
# 0        19.451613
# 1        17.655172
# 2        13.645161
# 3         8.966667
# 4         6.967742
#            ...
# 12931    73.032258
# 12932    64.833333
# 12933    38.774194
# 12934    37.200000
# 12935    32.580645
# Length: 12936, dtype: float64

# %%
df['VALUE'] = df_d.mean(axis=1)

# %%
df
# Out:
#        PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 0             28         79         4         1  28079004_1_38  2008    1
# 1             28         79         4         1  28079004_1_38  2008    2
# 2             28         79         4         1  28079004_1_38  2008    3
# 3             28         79         4         1  28079004_1_38  2008    4
# 4             28         79         4         1  28079004_1_38  2008    5
# ...          ...        ...       ...       ...            ...   ...  ...
# 12931         28         79        60        14  28079060_14_6  2015    8
# 12932         28         79        60        14  28079060_14_6  2015    9
# 12933         28         79        60        14  28079060_14_6  2015   10
# 12934         28         79        60        14  28079060_14_6  2015   11
# 12935         28         79        60        14  28079060_14_6  2015   12
#
#         D01 V01   D02  ... V27   D28 V28   D29 V29   D30 V30   D31 V31  \
# 0      20.0   V  20.0  ...   V  30.0   V  24.0   V  27.0   V  20.0   V
# 1      23.0   V  16.0  ...   V  14.0   V  17.0   V   0.0   N   0.0   N
# 2      17.0   V  16.0  ...   V  14.0   V  13.0   V  11.0   V  11.0   V
# 3      14.0   V  11.0  ...   V   7.0   V   6.0   V   7.0   V   0.0   N
# 4       7.0   V   8.0  ...   V   7.0   V   7.0   V   7.0   V   7.0   V
# ...     ...  ..   ...  ...  ..   ...  ..   ...  ..   ...  ..   ...  ..
# 12931  90.0   V  81.0  ...   V  64.0   V  88.0   V  71.0   V  40.0   V
# 12932  53.0   V  70.0  ...   V  66.0   V  60.0   V  58.0   V   0.0   N
# 12933  51.0   V  68.0  ...   V  62.0   V  45.0   V  28.0   V  54.0   V
# 12934  61.0   V  57.0  ...   V  49.0   V  45.0   V  33.0   V   0.0   N
# 12935  33.0   V  25.0  ...   V  42.0   V  45.0   V  43.0   V  32.0   V
#
#            VALUE
# 0      19.451613
# 1      17.655172
# 2      13.645161
# 3       8.966667
# 4       6.967742
# ...          ...
# 12931  73.032258
# 12932  64.833333
# 12933  38.774194
# 12934  37.200000
# 12935  32.580645
#
# [12936 rows x 70 columns]

# %%
df.isnull().sum()
# Out:
# PROVINCIA         0
# MUNICIPIO         0
# ESTACION          0
# MAGNITUD          0
# PUNTO_MUESTREO    0
#                  ..
# D30               0
# V30               0
# D31               0
# V31               0
# VALUE             2
# Length: 70, dtype: int64

# %%
df = df[['PUNTO_MUESTREO','ANO','MES','VALUE']]

# %%
df
# Out:
#       PUNTO_MUESTREO   ANO  MES      VALUE
# 0      28079004_1_38  2008    1  19.451613
# 1      28079004_1_38  2008    2  17.655172
# 2      28079004_1_38  2008    3  13.645161
# 3      28079004_1_38  2008    4   8.966667
# 4      28079004_1_38  2008    5   6.967742
# ...              ...   ...  ...        ...
# 12931  28079060_14_6  2015    8  73.032258
# 12932  28079060_14_6  2015    9  64.833333
# 12933  28079060_14_6  2015   10  38.774194
# 12934  28079060_14_6  2015   11  37.200000
# 12935  28079060_14_6  2015   12  32.580645
#
# [12936 rows x 4 columns]

# %%
df['FECHA'] = df['ANO'].astype(str) + '-' + df['MES'].astype(str)
# Out:
# C:\Users\eruit\AppData\Local\Temp\ipykernel_12668\3405512352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FECHA'] = df['ANO'].astype(str) + '-' + df['MES'].astype(str)

# %%
df['FECHA'] = pd.to_datetime(df['FECHA'])
# Out:
# C:\Users\eruit\AppData\Local\Temp\ipykernel_12668\2142312632.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FECHA'] = pd.to_datetime(df['FECHA'])

# %%
df.dtypes
# Out:
# PUNTO_MUESTREO            object
# ANO                        int64
# MES                        int64
# VALUE                    float64
# FECHA             datetime64[ns]
# dtype: object

# %%
import plotly.express as px

# %%
px.line(df, x='FECHA', y='VALUE', color='PUNTO_MUESTREO')

# %%
df.describe()
# Out:
#                 ANO           MES         VALUE
# count  12936.000000  12936.000000  12934.000000
# mean    2011.873145      6.523887     30.227789
# std        2.139417      3.458927     52.419830
# min     2008.000000      1.000000      0.028333
# 25%     2010.000000      4.000000      2.676063
# 50%     2012.000000      7.000000     19.233333
# 75%     2014.000000     10.000000     44.600000
# max     2015.000000     12.000000   3180.612903
